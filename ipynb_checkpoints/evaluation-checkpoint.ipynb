# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
import cv2  # Install opencv-python
import numpy as np
import os
from PIL import Image, ImageOps

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_model_3.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# %% [raw]
# 0 Sitting
# 1 Standing
# 2 Lying_Down
# 3 Nothing

# %%
total = 0
correct = 0

# %% [markdown]
# #### Testing on Lying Down

# %%
# Folder containing the images
folder_path = 'test_lyingdown'

# List all files in the folder
files = os.listdir(folder_path)

# Loop through files
for file in files:
    image_path = os.path.join(folder_path, file)

    # Create the array of the right shape to feed into the keras model
    # The 'length' or number of images you can put into the array is
    # determined by the first position in the shape tuple, in this case 1
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

    # Replace this with the path to your image
    image = Image.open(image_path).convert("RGB")

    # resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

    # turn the image into a numpy array
    image_array = np.asarray(image)

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

    # Load the image into the array
    data[0] = normalized_image_array

    # Predicts the model
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)
    
    if(index==2):
        correct+=1
    
    total+=1
# Out:
# 1/1 [==============================] - 1s 651ms/step
# Class: Lying_Down
# Confidence Score: 0.99766964
# 1/1 [==============================] - 0s 61ms/step
# Class: Lying_Down
# Confidence Score: 0.99953854
# 1/1 [==============================] - 0s 20ms/step
# Class: Lying_Down
# Confidence Score: 0.9447153
# 1/1 [==============================] - 0s 20ms/step
# Class: Lying_Down
# Confidence Score: 0.9989768
# 1/1 [==============================] - 0s 21ms/step
# Class: Lying_Down
# Confidence Score: 1.0
# 1/1 [==============================] - 0s 21ms/step
# Class: Lying_Down
# Confidence Score: 0.99999976
# 1/1 [==============================] - 0s 21ms/step
# Class: Lying_Down
# Confidence Score: 0.9999894
# 1/1 [==============================] - 0s 19ms/step
# Class: Lying_Down
# Confidence Score: 0.99999905
# 1/1 [==============================] - 0s 20ms/step
# Class: Lying_Down
# Confidence Score: 0.99435836
# 1/1 [==============================] - 0s 26ms/step
# Class: Standing
# Confidence Score: 0.5121301
# 1/1 [==============================] - 0s 27ms/step
# Class: Lying_Down
# Confidence Score: 0.9978734
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 33ms/step
# Class: Lying_Down
# Confidence Score: 1.0
# 1/1 [==============================] - 0s 27ms/step
# Class: Lying_Down
# Confidence Score: 1.0
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.99997926
# 1/1 [==============================] - 0s 23ms/step
# Class: Lying_Down
# Confidence Score: 0.99999535
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.9999975
# 1/1 [==============================] - 0s 41ms/step
# Class: Lying_Down
# Confidence Score: 0.997474
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.9991301
# 1/1 [==============================] - 0s 23ms/step
# Class: Lying_Down
# Confidence Score: 0.9999995
# 1/1 [==============================] - 0s 29ms/step
# Class: Lying_Down
# Confidence Score: 0.99999845
# 1/1 [==============================] - 0s 43ms/step
# Class: Lying_Down
# Confidence Score: 0.9999479
# 1/1 [==============================] - 0s 42ms/step
# Class: Lying_Down
# Confidence Score: 0.99995935
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.9997961
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.9999908
# 1/1 [==============================] - 0s 27ms/step
# Class: Lying_Down
# Confidence Score: 0.99999523
# 1/1 [==============================] - 0s 24ms/step
# Class: Lying_Down
# Confidence Score: 1.0
# 1/1 [==============================] - 0s 41ms/step
# Class: Lying_Down
# Confidence Score: 0.9999999
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.99992156
# 1/1 [==============================] - 0s 27ms/step
# Class: Lying_Down
# Confidence Score: 0.99996364
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.9999839
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.9999956
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.99997914
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.9999677
# 1/1 [==============================] - 0s 34ms/step
# Class: Lying_Down
# Confidence Score: 0.9996792
# 1/1 [==============================] - 0s 30ms/step
# Class: Lying_Down
# Confidence Score: 0.99927944
# 1/1 [==============================] - 0s 42ms/step
# Class: Lying_Down
# Confidence Score: 0.9999982
# 1/1 [==============================] - 0s 27ms/step
# Class: Lying_Down
# Confidence Score: 0.99999964
# 1/1 [==============================] - 0s 23ms/step
# Class: Lying_Down
# Confidence Score: 0.9999926
# 1/1 [==============================] - 0s 25ms/step
# Class: Lying_Down
# Confidence Score: 0.9986481
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.99995327
# 1/1 [==============================] - 0s 26ms/step
# Class: Lying_Down
# Confidence Score: 0.9999819
# 1/1 [==============================] - 0s 31ms/step
# Class: Lying_Down
# Confidence Score: 0.9789058
# 1/1 [==============================] - 0s 24ms/step
# Class: Lying_Down
# Confidence Score: 0.99294245
# 1/1 [==============================] - 0s 24ms/step
# Class: Lying_Down
# Confidence Score: 0.9997212
# 1/1 [==============================] - 0s 23ms/step
# Class: Lying_Down
# Confidence Score: 0.9994149

# %% [markdown]
# #### Testing on Nothing

# %%
# Folder containing the images
folder_path = 'test_nothing'

# List all files in the folder
files = os.listdir(folder_path)

# Loop through files
for file in files:
    image_path = os.path.join(folder_path, file)

    # Create the array of the right shape to feed into the keras model
    # The 'length' or number of images you can put into the array is
    # determined by the first position in the shape tuple, in this case 1
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

    # Replace this with the path to your image
    image = Image.open(image_path).convert("RGB")

    # resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

    # turn the image into a numpy array
    image_array = np.asarray(image)

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

    # Load the image into the array
    data[0] = normalized_image_array

    # Predicts the model
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)
    
    if(index==3):
        correct+=1
    
    total+=1
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Class: Nothing
# Confidence Score: 0.9995633
# 1/1 [==============================] - 0s 26ms/step
# Class: Nothing
# Confidence Score: 0.9998919
# 1/1 [==============================] - 0s 27ms/step
# Class: Nothing
# Confidence Score: 0.99983597
# 1/1 [==============================] - 0s 23ms/step
# Class: Nothing
# Confidence Score: 0.9980363
# 1/1 [==============================] - 0s 25ms/step
# Class: Nothing
# Confidence Score: 0.9998739
# 1/1 [==============================] - 0s 29ms/step
# Class: Nothing
# Confidence Score: 0.9999721
# 1/1 [==============================] - 0s 41ms/step
# Class: Nothing
# Confidence Score: 0.99991655
# 1/1 [==============================] - 0s 39ms/step
# Class: Nothing
# Confidence Score: 0.9996655
# 1/1 [==============================] - 0s 52ms/step
# Class: Nothing
# Confidence Score: 0.9999833
# 1/1 [==============================] - 0s 46ms/step
# Class: Nothing
# Confidence Score: 0.99993384
# 1/1 [==============================] - 0s 25ms/step
# Class: Nothing
# Confidence Score: 0.9999887
# 1/1 [==============================] - 0s 59ms/step
# Class: Nothing
# Confidence Score: 0.9997075
# 1/1 [==============================] - 0s 55ms/step
# Class: Nothing
# Confidence Score: 0.9997615
# 1/1 [==============================] - 0s 43ms/step
# Class: Nothing
# Confidence Score: 0.99825484
# 1/1 [==============================] - 0s 57ms/step
# Class: Nothing
# Confidence Score: 0.99968016
# 1/1 [==============================] - 0s 51ms/step
# Class: Nothing
# Confidence Score: 0.9996107
# 1/1 [==============================] - 0s 58ms/step
# Class: Nothing
# Confidence Score: 0.9989825
# 1/1 [==============================] - 0s 56ms/step
# Class: Nothing
# Confidence Score: 0.99993825
# 1/1 [==============================] - 0s 43ms/step
# Class: Nothing
# Confidence Score: 0.99993646
# 1/1 [==============================] - 0s 47ms/step
# Class: Nothing
# Confidence Score: 0.99997723
# 1/1 [==============================] - 0s 40ms/step
# Class: Nothing
# Confidence Score: 0.9999919
# 1/1 [==============================] - 0s 49ms/step
# Class: Nothing
# Confidence Score: 0.99995077
# 1/1 [==============================] - 0s 42ms/step
# Class: Nothing
# Confidence Score: 0.9999355
# 1/1 [==============================] - 0s 44ms/step
# Class: Nothing
# Confidence Score: 0.99998367
# 1/1 [==============================] - 0s 34ms/step
# Class: Nothing
# Confidence Score: 0.9999951
# 1/1 [==============================] - 0s 50ms/step
# Class: Nothing
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 50ms/step
# Class: Nothing
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 46ms/step
# Class: Nothing
# Confidence Score: 0.9991048
# 1/1 [==============================] - 0s 49ms/step
# Class: Nothing
# Confidence Score: 0.99941874
# 1/1 [==============================] - 0s 52ms/step
# Class: Nothing
# Confidence Score: 0.9999206
# 1/1 [==============================] - 0s 53ms/step
# Class: Nothing
# Confidence Score: 0.9999168
# 1/1 [==============================] - 0s 27ms/step
# Class: Nothing
# Confidence Score: 0.9999777
# 1/1 [==============================] - 0s 59ms/step
# Class: Nothing
# Confidence Score: 0.9998288
# 1/1 [==============================] - 0s 49ms/step
# Class: Nothing
# Confidence Score: 0.96412015
# 1/1 [==============================] - 0s 41ms/step
# Class: Nothing
# Confidence Score: 0.98044807

# %% [markdown]
# #### Testing on Sitting

# %%
# Folder containing the images
folder_path = 'test_sitting'

# List all files in the folder
files = os.listdir(folder_path)

# Loop through files
for file in files:
    image_path = os.path.join(folder_path, file)

    # Create the array of the right shape to feed into the keras model
    # The 'length' or number of images you can put into the array is
    # determined by the first position in the shape tuple, in this case 1
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

    # Replace this with the path to your image
    image = Image.open(image_path).convert("RGB")

    # resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

    # turn the image into a numpy array
    image_array = np.asarray(image)

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.978893
# 1/1 [==============================] - 0s 65ms/step
# Class: Lying_Down
# Confidence Score: 0.99693334
# 1/1 [==============================] - 0s 53ms/step
# Class: Lying_Down
# Confidence Score: 0.8807974
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.9264495
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.98358256
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.99408746
# 1/1 [==============================] - 0s 49ms/step
# Class: Lying_Down
# Confidence Score: 0.9965491
# 1/1 [==============================] - 0s 54ms/step
# Class: Lying_Down
# Confidence Score: 0.99354905
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.9924117
# 1/1 [==============================] - 0s 50ms/step
# Class: Lying_Down
# Confidence Score: 0.91803336
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.5660964
# 1/1 [==============================] - 0s 52ms/step
# Class: Sitting
# Confidence Score: 0.6207064
# 1/1 [==============================] - 0s 53ms/step
# Class: Sitting
# Confidence Score: 0.6939086
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.99816316
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.9994393
# 1/1 [==============================] - 0s 45ms/step
# Class: Lying_Down
# Confidence Score: 0.9476712
# 1/1 [==============================] - 0s 46ms/step
# Class: Lying_Down
# Confidence Score: 0.68741584
# 1/1 [==============================] - 0s 45ms/step
# Class: Lying_Down
# Confidence Score: 0.9998275
# 1/1 [==============================] - 0s 54ms/step
# Class: Lying_Down
# Confidence Score: 0.99968874
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.99993694
# 1/1 [==============================] - 0s 48ms/step
# Class: Lying_Down
# Confidence Score: 0.9969207
# 1/1 [==============================] - 0s 54ms/step
# Class: Lying_Down
# Confidence Score: 0.99560994
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.97431177
# 1/1 [==============================] - 0s 50ms/step
# Class: Lying_Down
# Confidence Score: 0.96812737
# 1/1 [==============================] - 0s 58ms/step
# Class: Lying_Down
# Confidence Score: 0.9946075
# 1/1 [==============================] - 0s 53ms/step
# Class: Lying_Down
# Confidence Score: 0.9773252
# 1/1 [==============================] - 0s 56ms/step
# Class: Lying_Down
# Confidence Score: 0.9998393
# 1/1 [==============================] - 0s 50ms/step
# Class: Lying_Down
# Confidence Score: 0.99976546
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.9994025
# 1/1 [==============================] - 0s 51ms/step
# Class: Lying_Down
# Confidence Score: 0.9993284
# 1/1 [==============================] - 0s 46ms/step
# Class: Lying_Down
# Confidence Score: 0.9898761
# 1/1 [==============================] - 0s 52ms/step
# Class: Lying_Down
# Confidence Score: 0.8812685
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.99617153
# 1/1 [==============================] - 0s 55ms/step
# Class: Lying_Down
# Confidence Score: 0.97957325

# %% [markdown]
# #### Testing on Standing

# %%
# Folder containing the images
folder_path = 'test_standing'

# List all files in the folder
files = os.listdir(folder_path)

# Loop through files
for file in files:
    image_path = os.path.join(folder_path, file)

    # Create the array of the right shape to feed into the keras model
    # The 'length' or number of images you can put into the array is
    # determined by the first position in the shape tuple, in this case 1
    data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

    # Replace this with the path to your image
    image = Image.open(image_path).convert("RGB")

    # resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

    # turn the image into a numpy array
    image_array = np.asarray(image)

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

    # Load the image into the array
    data[0] = normalized_image_array

    # Predicts the model
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)
    
    if(index==1):
        correct+=1
    
    total+=1
# Out:
# 1/1 [==============================] - 0s 31ms/step
#
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 53ms/step
# Class: Standing
# Confidence Score: 0.99999976
# 1/1 [==============================] - 0s 50ms/step
# Class: Standing
# Confidence Score: 0.99994445
# 1/1 [==============================] - 0s 58ms/step
# Class: Standing
# Confidence Score: 0.9999572
# 1/1 [==============================] - 0s 56ms/step
# Class: Standing
# Confidence Score: 0.99999714
# 1/1 [==============================] - 0s 54ms/step
# Class: Standing
# Confidence Score: 0.9999995
# 1/1 [==============================] - 0s 55ms/step
# Class: Standing
# Confidence Score: 0.9999993
# 1/1 [==============================] - 0s 48ms/step
# Class: Standing
# Confidence Score: 0.9995627
# 1/1 [==============================] - 0s 56ms/step
# Class: Standing
# Confidence Score: 1.0
# 1/1 [==============================] - 0s 38ms/step
# Class: Standing
# Confidence Score: 0.9999974
# 1/1 [==============================] - 0s 50ms/step
# Class: Standing
# Confidence Score: 0.99893385
# 1/1 [==============================] - 0s 46ms/step
# Class: Standing
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 49ms/step
# Class: Standing
# Confidence Score: 0.9999962
# 1/1 [==============================] - 0s 49ms/step
# Class: Standing
# Confidence Score: 0.99999845
# 1/1 [==============================] - 0s 51ms/step
# Class: Standing
# Confidence Score: 0.99999833
# 1/1 [==============================] - 0s 67ms/step
# Class: Standing
# Confidence Score: 0.9989911
# 1/1 [==============================] - 0s 55ms/step
# Class: Standing
# Confidence Score: 0.9749093
# 1/1 [==============================] - 0s 55ms/step
# Class: Standing
# Confidence Score: 0.9999732
# 1/1 [==============================] - 0s 40ms/step
# Class: Standing
# Confidence Score: 0.99999976
# 1/1 [==============================] - 0s 49ms/step
# Class: Standing
# Confidence Score: 0.99974173
# 1/1 [==============================] - 0s 54ms/step
# Class: Standing
# Confidence Score: 0.996601
# 1/1 [==============================] - 0s 55ms/step
# Class: Standing
# Confidence Score: 0.999393
# 1/1 [==============================] - 0s 46ms/step
# Class: Standing
# Confidence Score: 0.9999994
# 1/1 [==============================] - 0s 51ms/step
# Class: Standing
# Confidence Score: 0.9999858
# 1/1 [==============================] - 0s 50ms/step
# Class: Standing
# Confidence Score: 0.99999714
# 1/1 [==============================] - 0s 27ms/step
# Class: Standing
# Confidence Score: 0.99999964
# 1/1 [==============================] - 0s 45ms/step
# Class: Standing
# Confidence Score: 0.99999976
# 1/1 [==============================] - 0s 51ms/step
# Class: Standing
# Confidence Score: 0.9998448
# 1/1 [==============================] - 0s 52ms/step
# Class: Standing
# Confidence Score: 0.999951
# 1/1 [==============================] - 0s 47ms/step
# Class: Standing
# Confidence Score: 0.9996953
# 1/1 [==============================] - 0s 45ms/step
# Class: Standing
# Confidence Score: 0.9995265
# 1/1 [==============================] - 0s 53ms/step
# Class: Standing
# Confidence Score: 0.9999895

# %% [markdown]
# ### Accuracy

# %%
print(f"The accuracy is {(correct/total) * 100} %")
# Out:
# The accuracy is 75.45454545454545 %
